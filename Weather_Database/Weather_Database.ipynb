# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
                    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | kostino
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | broome
# Processing Record 7 of Set 1 | nieuw amsterdam
# Processing Record 8 of Set 1 | waipawa
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | perth
# Processing Record 19 of Set 1 | udachnyy
# Processing Record 20 of Set 1 | veracruz
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | bend
# Processing Record 25 of Set 1 | zhaotong
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | daoukro
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | taber
# Processing Record 31 of Set 1 | saint-louis
# Processing Record 32 of Set 1 | grindavik
# Processing Record 33 of Set 1 | vung tau
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | sao borja
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | linxia
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | aasiaat
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | bandarbeyla
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | buon me thuot
# City not found. Skipping...
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | rocha
# Processing Record 8 of Set 2 | rio branco do sul
# Processing Record 9 of Set 2 | norrtalje
# Processing Record 10 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 11 of Set 2 | nsoko
# Processing Record 12 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 2 | batemans bay
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | ust-karsk
# Processing Record 19 of Set 2 | sampit
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | dondo
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | barreirinhas
# Processing Record 25 of Set 2 | pascagoula
# Processing Record 26 of Set 2 | tuatapere
# Processing Record 27 of Set 2 | kahului
# Processing Record 28 of Set 2 | sept-iles
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | marienburg
# Processing Record 32 of Set 2 | bermeo
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | lahaina
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | sokolo
# Processing Record 38 of Set 2 | atambua
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | itarema
# Processing Record 41 of Set 2 | tholey
# Processing Record 42 of Set 2 | griffith
# Processing Record 43 of Set 2 | touros
# Processing Record 44 of Set 2 | coffs harbour
# Processing Record 45 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 2 | alta gracia
# Processing Record 47 of Set 2 | port arthur
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | casablanca
# Processing Record 50 of Set 2 | vrangel
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | mapiripan
# Processing Record 4 of Set 3 | kirensk
# Processing Record 5 of Set 3 | pauini
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 3 | jensen beach
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | najran
# Processing Record 12 of Set 3 | sidi bu zayd
# City not found. Skipping...
# Processing Record 13 of Set 3 | kieta
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | alugan
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | hirara
# Processing Record 18 of Set 3 | hurghada
# Processing Record 19 of Set 3 | itororo
# Processing Record 20 of Set 3 | chokurdakh
# Processing Record 21 of Set 3 | vardo
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | swellendam
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | nakskov
# Processing Record 28 of Set 3 | clinton
# Processing Record 29 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 3 | zhigansk
# Processing Record 31 of Set 3 | rongcheng
# Processing Record 32 of Set 3 | beitbridge
# Processing Record 33 of Set 3 | jutai
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | severobaykalsk
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 3 | amalfi
# Processing Record 39 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | juneau
# Processing Record 43 of Set 3 | new norfolk
# Processing Record 44 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 3 | tilichiki
# Processing Record 46 of Set 3 | abu zabad
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | andenes
# Processing Record 49 of Set 3 | pau brasil
# Processing Record 50 of Set 3 | bardiyah
# Processing Record 1 of Set 4 | olinda
# Processing Record 2 of Set 4 | badaojiang
# City not found. Skipping...
# Processing Record 3 of Set 4 | solna
# Processing Record 4 of Set 4 | matara
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | kimparana
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | solnechnyy
# Processing Record 12 of Set 4 | itaqui
# Processing Record 13 of Set 4 | frolovo
# Processing Record 14 of Set 4 | prieska
# Processing Record 15 of Set 4 | novominskaya
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | ust-kut
# Processing Record 19 of Set 4 | salinopolis
# Processing Record 20 of Set 4 | hithadhoo
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | kashi
# Processing Record 24 of Set 4 | muisne
# Processing Record 25 of Set 4 | karratha
# Processing Record 26 of Set 4 | necocli
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | wanning
# Processing Record 30 of Set 4 | plastun
# Processing Record 31 of Set 4 | bud
# Processing Record 32 of Set 4 | bichena
# Processing Record 33 of Set 4 | haifa
# Processing Record 34 of Set 4 | gandai
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | assiniboia
# Processing Record 37 of Set 4 | turukhansk
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | reyes
# Processing Record 41 of Set 4 | tavda
# Processing Record 42 of Set 4 | oyem
# Processing Record 43 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 4 | pahrump
# Processing Record 45 of Set 4 | bilibino
# Processing Record 46 of Set 4 | bubaque
# Processing Record 47 of Set 4 | port augusta
# Processing Record 48 of Set 4 | glendive
# Processing Record 49 of Set 4 | puerto carreno
# Processing Record 50 of Set 4 | san pedro carcha
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | san jose
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | north bend
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | doha
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | sayaxche
# Processing Record 10 of Set 5 | havoysund
# Processing Record 11 of Set 5 | krasnogorskoye
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | tura
# Processing Record 14 of Set 5 | bela vista de goias
# Processing Record 15 of Set 5 | loandjili
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | banjar
# Processing Record 18 of Set 5 | cedar city
# Processing Record 19 of Set 5 | coldstream
# Processing Record 20 of Set 5 | kalmunai
# Processing Record 21 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | caracuaro
# Processing Record 23 of Set 5 | avarua
# Processing Record 24 of Set 5 | srednekolymsk
# Processing Record 25 of Set 5 | port hardy
# Processing Record 26 of Set 5 | sinnamary
# Processing Record 27 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 5 | nome
# Processing Record 29 of Set 5 | baley
# Processing Record 30 of Set 5 | puerto pinasco
# City not found. Skipping...
# Processing Record 31 of Set 5 | gushikawa
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | dong hoi
# Processing Record 34 of Set 5 | dodge city
# Processing Record 35 of Set 5 | safaga
# Processing Record 36 of Set 5 | sakakah
# Processing Record 37 of Set 5 | ampanihy
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | egvekinot
# Processing Record 40 of Set 5 | ola
# Processing Record 41 of Set 5 | vestmannaeyjar
# Processing Record 42 of Set 5 | valdivia
# Processing Record 43 of Set 5 | labuhan
# Processing Record 44 of Set 5 | nkoteng
# Processing Record 45 of Set 5 | billings
# Processing Record 46 of Set 5 | borzya
# Processing Record 47 of Set 5 | kodiak
# Processing Record 48 of Set 5 | sao joao da barra
# Processing Record 49 of Set 5 | yar-sale
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | arraial do cabo
# Processing Record 2 of Set 6 | olafsvik
# Processing Record 3 of Set 6 | cap malheureux
# Processing Record 4 of Set 6 | xuddur
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | mandalgovi
# Processing Record 7 of Set 6 | nanga eboko
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | atuona
# Processing Record 10 of Set 6 | longyan
# Processing Record 11 of Set 6 | airai
# Processing Record 12 of Set 6 | san cristobal
# Processing Record 13 of Set 6 | aborlan
# Processing Record 14 of Set 6 | marsaxlokk
# Processing Record 15 of Set 6 | aswan
# Processing Record 16 of Set 6 | arkhipo-osipovka
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | harper
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | faya
# Processing Record 22 of Set 6 | coquimbo
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | nishihara
# Processing Record 25 of Set 6 | ambon
# Processing Record 26 of Set 6 | vagur
# Processing Record 27 of Set 6 | whitehorse
# Processing Record 28 of Set 6 | buchanan
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | guane
# Processing Record 31 of Set 6 | ler
# Processing Record 32 of Set 6 | yantal
# Processing Record 33 of Set 6 | seoul
# Processing Record 34 of Set 6 | puerto baquerizo moreno
# Processing Record 35 of Set 6 | west wendover
# Processing Record 36 of Set 6 | olesno
# Processing Record 37 of Set 6 | tagusao
# Processing Record 38 of Set 6 | bonoua
# Processing Record 39 of Set 6 | kangaatsiaq
# Processing Record 40 of Set 6 | ensley
# Processing Record 41 of Set 6 | cadillac
# Processing Record 42 of Set 6 | teluknaga
# Processing Record 43 of Set 6 | nelson bay
# Processing Record 44 of Set 6 | tromso
# Processing Record 45 of Set 6 | sigerfjord
# City not found. Skipping...
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | huangmei
# Processing Record 48 of Set 6 | ahuimanu
# Processing Record 49 of Set 6 | tezu
# Processing Record 50 of Set 6 | santa isabel do rio negro
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | iiyama
# Processing Record 5 of Set 7 | teguise
# Processing Record 6 of Set 7 | puerto leguizamo
# Processing Record 7 of Set 7 | severo-kurilsk
# Processing Record 8 of Set 7 | kumluca
# Processing Record 9 of Set 7 | tupik
# Processing Record 10 of Set 7 | talara
# Processing Record 11 of Set 7 | montreal
# Processing Record 12 of Set 7 | krapkowice
# Processing Record 13 of Set 7 | ugoofaaru
# Processing Record 14 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | solok
# Processing Record 17 of Set 7 | batagay-alyta
# Processing Record 18 of Set 7 | rio grande
# Processing Record 19 of Set 7 | sergeyevka
# Processing Record 20 of Set 7 | salalah
# Processing Record 21 of Set 7 | misratah
# Processing Record 22 of Set 7 | kupang
# Processing Record 23 of Set 7 | kharp
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | vilhena
# Processing Record 26 of Set 7 | oussouye
# Processing Record 27 of Set 7 | skibbereen
# Processing Record 28 of Set 7 | zgierz
# Processing Record 29 of Set 7 | kirakira
# Processing Record 30 of Set 7 | onega
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 7 | dwarka
# Processing Record 34 of Set 7 | sibolga
# Processing Record 35 of Set 7 | coshocton
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | celestun
# Processing Record 38 of Set 7 | ranong
# Processing Record 39 of Set 7 | warmbad
# Processing Record 40 of Set 7 | khandyga
# Processing Record 41 of Set 7 | contamana
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | alto baudo
# City not found. Skipping...
# Processing Record 44 of Set 7 | ashqelon
# Processing Record 45 of Set 7 | tignere
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | qibili
# City not found. Skipping...
# Processing Record 49 of Set 7 | gazojak
# Processing Record 50 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 1 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 8 | ustyuzhna
# Processing Record 3 of Set 8 | ballitoville
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | cayenne
# Processing Record 8 of Set 8 | saint-georges
# Processing Record 9 of Set 8 | nuuk
# Processing Record 10 of Set 8 | samarai
# Processing Record 11 of Set 8 | tirumullaivasal
# Processing Record 12 of Set 8 | ngorongoro
# Processing Record 13 of Set 8 | inverell
# Processing Record 14 of Set 8 | dalvik
# Processing Record 15 of Set 8 | burnie
# Processing Record 16 of Set 8 | kunya
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | sobolevo
# Processing Record 19 of Set 8 | victor harbor
# Processing Record 20 of Set 8 | ust-maya
# Processing Record 21 of Set 8 | thinadhoo
# Processing Record 22 of Set 8 | terra santa
# Processing Record 23 of Set 8 | vazhiny
# Processing Record 24 of Set 8 | half moon bay
# Processing Record 25 of Set 8 | alyangula
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | ilave
# Processing Record 28 of Set 8 | kutum
# Processing Record 29 of Set 8 | vilyuysk
# Processing Record 30 of Set 8 | akureyri
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | ayr
# Processing Record 34 of Set 8 | aitape
# Processing Record 35 of Set 8 | kosa
# Processing Record 36 of Set 8 | payo
# Processing Record 37 of Set 8 | liepaja
# Processing Record 38 of Set 8 | aykhal
# Processing Record 39 of Set 8 | san rafael del sur
# Processing Record 40 of Set 8 | gambela
# Processing Record 41 of Set 8 | mount gambier
# Processing Record 42 of Set 8 | taywarah
# Processing Record 43 of Set 8 | radhanpur
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | dombarovskiy
# Processing Record 46 of Set 8 | dingle
# Processing Record 47 of Set 8 | orotukan
# Processing Record 48 of Set 8 | sebrovo
# Processing Record 49 of Set 8 | zolotukhino
# Processing Record 50 of Set 8 | ban nahin
# Processing Record 1 of Set 9 | la tijera
# Processing Record 2 of Set 9 | tyup
# Processing Record 3 of Set 9 | tessalit
# Processing Record 4 of Set 9 | yanliang
# Processing Record 5 of Set 9 | cartagena del chaira
# Processing Record 6 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 9 | alta floresta
# Processing Record 8 of Set 9 | benguela
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | turan
# Processing Record 11 of Set 9 | buritama
# Processing Record 12 of Set 9 | rudbar
# Processing Record 13 of Set 9 | byron bay
# Processing Record 14 of Set 9 | alamosa
# Processing Record 15 of Set 9 | pando
# Processing Record 16 of Set 9 | curillo
# Processing Record 17 of Set 9 | nyurba
# Processing Record 18 of Set 9 | camapua
# Processing Record 19 of Set 9 | grandview
# Processing Record 20 of Set 9 | the pas
# Processing Record 21 of Set 9 | berlevag
# Processing Record 22 of Set 9 | ayan
# Processing Record 23 of Set 9 | carutapera
# Processing Record 24 of Set 9 | gamboma
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | itoman
# Processing Record 27 of Set 9 | meadow lake
# Processing Record 28 of Set 9 | monrovia
# Processing Record 29 of Set 9 | ardakan
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | ishigaki
# Processing Record 32 of Set 9 | ventspils
# Processing Record 33 of Set 9 | al
# City not found. Skipping...
# Processing Record 34 of Set 9 | marzuq
# Processing Record 35 of Set 9 | dole
# Processing Record 36 of Set 9 | aldan
# Processing Record 37 of Set 9 | ajdabiya
# Processing Record 38 of Set 9 | sovetskiy
# Processing Record 39 of Set 9 | ballina
# Processing Record 40 of Set 9 | atbasar
# Processing Record 41 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 9 | atar
# Processing Record 43 of Set 9 | zhuhai
# Processing Record 44 of Set 9 | bato
# Processing Record 45 of Set 9 | tautira
# Processing Record 46 of Set 9 | nizwa
# Processing Record 47 of Set 9 | filadelfia
# Processing Record 48 of Set 9 | lincoln
# Processing Record 49 of Set 9 | makushino
# Processing Record 50 of Set 9 | ipswich
# Processing Record 1 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 10 | raudeberg
# Processing Record 3 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 10 | te anau
# Processing Record 5 of Set 10 | tecoanapa
# Processing Record 6 of Set 10 | yingzhong
# City not found. Skipping...
# Processing Record 7 of Set 10 | quiindy
# Processing Record 8 of Set 10 | skeldon
# Processing Record 9 of Set 10 | nikolsk
# Processing Record 10 of Set 10 | mamallapuram
# Processing Record 11 of Set 10 | luba
# Processing Record 12 of Set 10 | pokhara
# Processing Record 13 of Set 10 | yuncheng
# Processing Record 14 of Set 10 | adrar
# Processing Record 15 of Set 10 | itupiranga
# Processing Record 16 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 10 | camacha
# Processing Record 18 of Set 10 | eureka
# Processing Record 19 of Set 10 | akcakoca
# Processing Record 20 of Set 10 | mutoko
# Processing Record 21 of Set 10 | devils lake
# Processing Record 22 of Set 10 | middle island
# Processing Record 23 of Set 10 | coari
# Processing Record 24 of Set 10 | henties bay
# Processing Record 25 of Set 10 | poshekhonye
# Processing Record 26 of Set 10 | bac lieu
# Processing Record 27 of Set 10 | balikpapan
# Processing Record 28 of Set 10 | laguna
# Processing Record 29 of Set 10 | korla
# Processing Record 30 of Set 10 | riyadh
# Processing Record 31 of Set 10 | ahipara
# Processing Record 32 of Set 10 | pemangkat
# Processing Record 33 of Set 10 | luan
# Processing Record 34 of Set 10 | lodingen
# Processing Record 35 of Set 10 | abalak
# Processing Record 36 of Set 10 | gobabis
# Processing Record 37 of Set 10 | marsh harbour
# Processing Record 38 of Set 10 | esmeraldas
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | shar
# Processing Record 42 of Set 10 | maturin
# Processing Record 43 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 10 | bathsheba
# Processing Record 45 of Set 10 | banyo
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | beaufort
# Processing Record 48 of Set 10 | phan thiet
# Processing Record 49 of Set 10 | francavilla al mare
# Processing Record 50 of Set 10 | aberdeen
# Processing Record 1 of Set 11 | ambanja
# Processing Record 2 of Set 11 | chimore
# Processing Record 3 of Set 11 | garowe
# Processing Record 4 of Set 11 | dullewala
# Processing Record 5 of Set 11 | beyneu
# Processing Record 6 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 11 | kindersley
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | bonavista
# Processing Record 10 of Set 11 | shimoda
# Processing Record 11 of Set 11 | darhan
# Processing Record 12 of Set 11 | tual
# Processing Record 13 of Set 11 | kiknur
# Processing Record 14 of Set 11 | gornopravdinsk
# Processing Record 15 of Set 11 | quepos
# Processing Record 16 of Set 11 | san antonio
# Processing Record 17 of Set 11 | sestu
# Processing Record 18 of Set 11 | gizo
# Processing Record 19 of Set 11 | may pen
# Processing Record 20 of Set 11 | elmira
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | laishevo
# Processing Record 23 of Set 11 | saint-pierre
# Processing Record 24 of Set 11 | auray
# Processing Record 25 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 11 | pimentel
# Processing Record 27 of Set 11 | jasper
# Processing Record 28 of Set 11 | novoagansk
# Processing Record 29 of Set 11 | moose jaw
# Processing Record 30 of Set 11 | los llanos de aridane
# Processing Record 31 of Set 11 | velyka lepetykha
# Processing Record 32 of Set 11 | severodvinsk
# Processing Record 33 of Set 11 | warrnambool
# Processing Record 34 of Set 11 | emba
# Processing Record 35 of Set 11 | sault sainte marie
# Processing Record 36 of Set 11 | troitsko-pechorsk
# Processing Record 37 of Set 11 | yanam
# Processing Record 38 of Set 11 | cabo san lucas
# Processing Record 39 of Set 11 | metro
# Processing Record 40 of Set 11 | hamilton
# Processing Record 41 of Set 11 | lagoa
# Processing Record 42 of Set 11 | kattivakkam
# Processing Record 43 of Set 11 | awbari
# Processing Record 44 of Set 11 | clyde river
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | tank
# Processing Record 47 of Set 11 | stabat
# Processing Record 48 of Set 11 | neiafu
# Processing Record 49 of Set 11 | dunmore east
# Processing Record 50 of Set 11 | buin
# Processing Record 1 of Set 12 | bayir
# Processing Record 2 of Set 12 | luanda
# Processing Record 3 of Set 12 | zatoka
# Processing Record 4 of Set 12 | port macquarie
# Processing Record 5 of Set 12 | koulikoro
# Processing Record 6 of Set 12 | willowmore
# Processing Record 7 of Set 12 | palembang
# Processing Record 8 of Set 12 | kisangani
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | champerico
# Processing Record 11 of Set 12 | teya
# Processing Record 12 of Set 12 | wanaka
# Processing Record 13 of Set 12 | igrim
# Processing Record 14 of Set 12 | burica
# City not found. Skipping...
# Processing Record 15 of Set 12 | lisakovsk
# Processing Record 16 of Set 12 | nantucket
# Processing Record 17 of Set 12 | anchorage
# Processing Record 18 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 12 | cuiluan
# Processing Record 20 of Set 12 | eyl
# Processing Record 21 of Set 12 | lae
# Processing Record 22 of Set 12 | alagoinha
# Processing Record 23 of Set 12 | presidente epitacio
# Processing Record 24 of Set 12 | kidal
# Processing Record 25 of Set 12 | panuco
# Processing Record 26 of Set 12 | bethanien
# Processing Record 27 of Set 12 | rovnoye
# Processing Record 28 of Set 12 | coromandel
# Processing Record 29 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 12 | santarem
# Processing Record 31 of Set 12 | quatre cocos
# Processing Record 32 of Set 12 | jodhpur
# Processing Record 33 of Set 12 | corbelia
# Processing Record 34 of Set 12 | grafton
# Processing Record 35 of Set 12 | cocorit
# Processing Record 36 of Set 12 | okmulgee
# Processing Record 37 of Set 12 | paragominas
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | jumla
# Processing Record 40 of Set 12 | nabire
# Processing Record 41 of Set 12 | lasa
# Processing Record 42 of Set 12 | majene
# Processing Record 43 of Set 12 | kuyanovo
# Processing Record 44 of Set 12 | northam
# Processing Record 45 of Set 12 | mulege
# Processing Record 46 of Set 12 | bollnas
# Processing Record 47 of Set 12 | nacala
# Processing Record 48 of Set 12 | george
# Processing Record 49 of Set 12 | oxford
# Processing Record 50 of Set 12 | lodja
# Processing Record 1 of Set 13 | virginia beach
# Processing Record 2 of Set 13 | amalapuram
# Processing Record 3 of Set 13 | rosarito
# Processing Record 4 of Set 13 | anyksciai
# Processing Record 5 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 13 | balabac
# Processing Record 7 of Set 13 | pimenta bueno
# Processing Record 8 of Set 13 | fort nelson
# Processing Record 9 of Set 13 | kutahya
# Processing Record 10 of Set 13 | panama city
# Processing Record 11 of Set 13 | madang
# Processing Record 12 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 13 | kabare
# Processing Record 14 of Set 13 | krasnoselkup
# Processing Record 15 of Set 13 | haines junction
# Processing Record 16 of Set 13 | korhogo
# Processing Record 17 of Set 13 | emerald
# Processing Record 18 of Set 13 | primorsk
# Processing Record 19 of Set 13 | kavieng
# Processing Record 20 of Set 13 | serenje
# Processing Record 21 of Set 13 | hermitage
# Processing Record 22 of Set 13 | gao
# Processing Record 23 of Set 13 | kloulklubed
# Processing Record 24 of Set 13 | broken hill
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | saint anthony
# Processing Record 27 of Set 13 | beloha
# Processing Record 28 of Set 13 | picota
# Processing Record 29 of Set 13 | port-cartier
# Processing Record 30 of Set 13 | sur
# Processing Record 31 of Set 13 | la asuncion
# Processing Record 32 of Set 13 | oktyabrskiy
# Processing Record 33 of Set 13 | cururupu
# Processing Record 34 of Set 13 | comodoro rivadavia
# Processing Record 35 of Set 13 | ixtapa
# Processing Record 36 of Set 13 | ancud
# Processing Record 37 of Set 13 | seymchan
# Processing Record 38 of Set 13 | fort-shevchenko
# Processing Record 39 of Set 13 | kawalu
# Processing Record 40 of Set 13 | tucurui
# Processing Record 41 of Set 13 | lazaro cardenas
# Processing Record 42 of Set 13 | kemin
# Processing Record 43 of Set 13 | benton harbor
# Processing Record 44 of Set 13 | luang prabang
# Processing Record 45 of Set 13 | ayacucho
# Processing Record 46 of Set 13 | sharlyk
# Processing Record 47 of Set 13 | puerto colombia
# Processing Record 48 of Set 13 | kaukauna
# Processing Record 49 of Set 13 | solwezi
# Processing Record 50 of Set 13 | parelhas
# Processing Record 1 of Set 14 | cockburn town
# Processing Record 2 of Set 14 | gasa
# Processing Record 3 of Set 14 | basco
# Processing Record 4 of Set 14 | posse
# Processing Record 5 of Set 14 | mouila
# Processing Record 6 of Set 14 | stornoway
# Processing Record 7 of Set 14 | minab
# Processing Record 8 of Set 14 | stromness
# Processing Record 9 of Set 14 | narsaq
# Processing Record 10 of Set 14 | sarangani
# Processing Record 11 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 14 | vostok
# Processing Record 13 of Set 14 | shelburne
# Processing Record 14 of Set 14 | san buenaventura
# Processing Record 15 of Set 14 | labuan
# Processing Record 16 of Set 14 | pochinok
# Processing Record 17 of Set 14 | puerto escondido
# Processing Record 18 of Set 14 | anjad
# Processing Record 19 of Set 14 | pabna
# Processing Record 20 of Set 14 | hervey bay
# Processing Record 21 of Set 14 | honiara
# Processing Record 22 of Set 14 | kitoy
# Processing Record 23 of Set 14 | ust-nera
# Processing Record 24 of Set 14 | chama
# Processing Record 25 of Set 14 | jimenez
# Processing Record 26 of Set 14 | pastavy
# Processing Record 27 of Set 14 | namibe
# Processing Record 28 of Set 14 | ust-barguzin
# Processing Record 29 of Set 14 | fresnillo
# Processing Record 30 of Set 14 | marquette
# Processing Record 31 of Set 14 | boguchar
# Processing Record 32 of Set 14 | soc trang
# Processing Record 33 of Set 14 | praia
# Processing Record 34 of Set 14 | belyy yar
# Processing Record 35 of Set 14 | biltine
# Processing Record 36 of Set 14 | conceicao do araguaia
# Processing Record 37 of Set 14 | nouadhibou
# Processing Record 38 of Set 14 | omsukchan
# Processing Record 39 of Set 14 | mapastepec
# Processing Record 40 of Set 14 | boyolangu
# Processing Record 41 of Set 14 | biak
# Processing Record 42 of Set 14 | terny
# Processing Record 43 of Set 14 | dicabisagan
# Processing Record 44 of Set 14 | saurimo
# Processing Record 45 of Set 14 | nouakchott
# Processing Record 46 of Set 14 | port blair
# Processing Record 47 of Set 14 | saravena
# Processing Record 48 of Set 14 | waldkirch
# Processing Record 49 of Set 14 | blackpool
# Processing Record 50 of Set 14 | dandong
# Processing Record 1 of Set 15 | bassano
# Processing Record 2 of Set 15 | awjilah
# Processing Record 3 of Set 15 | hualmay
# Processing Record 4 of Set 15 | shingu
# Processing Record 5 of Set 15 | buraydah
# Processing Record 6 of Set 15 | tacarigua
# Processing Record 7 of Set 15 | coahuayana
# Processing Record 8 of Set 15 | ravar
# Processing Record 9 of Set 15 | hilchenbach
# Processing Record 10 of Set 15 | atasu
# Processing Record 11 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 15 | noumea
# Processing Record 13 of Set 15 | trinidad
# Processing Record 14 of Set 15 | narok
# Processing Record 15 of Set 15 | shakhtinsk
# Processing Record 16 of Set 15 | vila velha
# Processing Record 17 of Set 15 | black river
# Processing Record 18 of Set 15 | batagay
# Processing Record 19 of Set 15 | pingliang
# Processing Record 20 of Set 15 | port hedland
# Processing Record 21 of Set 15 | walvis bay
# Processing Record 22 of Set 15 | aguimes
# Processing Record 23 of Set 15 | vao
# Processing Record 24 of Set 15 | pangnirtung
# Processing Record 25 of Set 15 | abbeville
# Processing Record 26 of Set 15 | sheregesh
# Processing Record 27 of Set 15 | namwala
# Processing Record 28 of Set 15 | orange cove
# Processing Record 29 of Set 15 | aykino
# Processing Record 30 of Set 15 | nueva concepcion
# Processing Record 31 of Set 15 | wajima
# Processing Record 32 of Set 15 | acarau
# Processing Record 33 of Set 15 | espanola
# Processing Record 34 of Set 15 | bereda
# Processing Record 35 of Set 15 | shujalpur
# Processing Record 36 of Set 15 | mangai
# Processing Record 37 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 15 | ulaangom
# Processing Record 40 of Set 15 | karakol
# Processing Record 41 of Set 15 | nanortalik
# Processing Record 42 of Set 15 | ewa beach
# Processing Record 43 of Set 15 | usinsk
# Processing Record 44 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 15 | cumana
# Processing Record 46 of Set 15 | evensk
# Processing Record 47 of Set 15 | changli
# Processing Record 48 of Set 15 | baherden
# Processing Record 49 of Set 15 | norsup
# Processing Record 50 of Set 15 | monte alegre de minas
# Processing Record 1 of Set 16 | ocos
# Processing Record 2 of Set 16 | buluang
# Processing Record 3 of Set 16 | lonavale
# Processing Record 4 of Set 16 | edremit
# Processing Record 5 of Set 16 | husavik
# Processing Record 6 of Set 16 | sabha
# Processing Record 7 of Set 16 | ossora
# Processing Record 8 of Set 16 | isangel
# Processing Record 9 of Set 16 | saquena
# Processing Record 10 of Set 16 | kungurtug
# Processing Record 11 of Set 16 | lulea
# Processing Record 12 of Set 16 | aksu
# Processing Record 13 of Set 16 | catabola
# Processing Record 14 of Set 16 | el paso
# Processing Record 15 of Set 16 | puerto lleras
# Processing Record 16 of Set 16 | iracoubo
# Processing Record 17 of Set 16 | bremgarten
# Processing Record 18 of Set 16 | qaqortoq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Lincoln -34.7333  135.8667     61.11        80          72
# 1             Hilo  19.7297 -155.0900     70.29        90          40
# 2        Saskylakh  71.9167  114.0833     33.22       100         100
# 3          Kostino  58.9097   53.2691     48.22        72         100
# 4           Broome  42.2506  -75.8330     50.85        95         100
# 5  Nieuw Amsterdam   5.8833  -55.0833     76.01        93          40
# 6          Waipawa -41.4122  175.5153     58.98        87         100
# 7           Albany  42.6001  -73.9662     48.94        91         100
# 8         Khatanga  71.9667  102.5000     20.93        89          96
# 9          Ushuaia -54.8000  -68.3000     33.46        69          75
#
#    Wind Speed Country Current Description
# 0        4.68      AU       broken clouds
# 1        5.75      US    scattered clouds
# 2        4.56      RU          light snow
# 3        9.24      RU     overcast clouds
# 4       11.50      US          light rain
# 5        0.00      SR    scattered clouds
# 6        8.41      NZ     overcast clouds
# 7        1.01      US       moderate rain
# 8        9.51      RU     overcast clouds
# 9        5.75      AR       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Lincoln      AU -34.7333  135.8667     61.11        80          72
# 1             Hilo      US  19.7297 -155.0900     70.29        90          40
# 2        Saskylakh      RU  71.9167  114.0833     33.22       100         100
# 3          Kostino      RU  58.9097   53.2691     48.22        72         100
# 4           Broome      US  42.2506  -75.8330     50.85        95         100
# 5  Nieuw Amsterdam      SR   5.8833  -55.0833     76.01        93          40
# 6          Waipawa      NZ -41.4122  175.5153     58.98        87         100
# 7           Albany      US  42.6001  -73.9662     48.94        91         100
# 8         Khatanga      RU  71.9667  102.5000     20.93        89          96
# 9          Ushuaia      AR -54.8000  -68.3000     33.46        69          75
#
#    Wind Speed Current Description
# 0        4.68       broken clouds
# 1        5.75    scattered clouds
# 2        4.56          light snow
# 3        9.24     overcast clouds
# 4       11.50          light rain
# 5        0.00    scattered clouds
# 6        8.41     overcast clouds
# 7        1.01       moderate rain
# 8        9.51     overcast clouds
# 9        5.75       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
